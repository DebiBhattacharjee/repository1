# %%
from tkinter import *
from PIL import ImageTk,Image 
import pymysql
from tkinter import messagebox

# %%
con = pymysql.connect(host="localhost",user="root",password='',database='db1')
cur = con.cursor()

# %%
def signupPage():
    global userInfo,passInfo,emailInfo,root,Canvas1,lb1,lb2,lb3,signupBtn,quitBtn
    root = Tk()
    root.title("Sign Up")
    root.maxsize(500,500) 
    root.geometry("500x500")
    
    Canvas1 = Canvas(root)
    Canvas1.config(bg="black")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg='red')
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.1)

    headingLabel = Label(headingFrame1, text=" Please Sign Up ", bg='red', font="Comicsansms 19 italic")
    headingLabel.pack()


    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.4,relwidth=0.8,relheight=0.4)
        
    lb1 = Label(labelFrame,text="Username : ", bg='black', fg='white')
    lb1.place(relx=0.05,rely=0.2, relheight=0.08)
        
    userInfo = Entry(labelFrame)
    userInfo.place(relx=0.3,rely=0.2, relwidth=0.62, relheight=0.08)
    
    lb2 = Label(labelFrame,text="Password : ", bg='black', fg='white')
    lb2.place(relx=0.05,rely=0.35, relheight=0.08)
        
    passInfo = Entry(labelFrame)
    passInfo.place(relx=0.3,rely=0.35, relwidth=0.62, relheight=0.08)
    
    lb3 = Label(labelFrame,text="Email ID : ", bg='black', fg='white')
    lb3.place(relx=0.05,rely=0.50, relheight=0.08)
        
    emailInfo = Entry(labelFrame)
    emailInfo.place(relx=0.3,rely=0.50, relwidth=0.62, relheight=0.08)
    
    signupBtn = Button(root,text="Sign Up",bg='green', fg='black',command=signup)
    signupBtn.place(relx=0.28,rely=0.9, relwidth=0.18,relheight=0.08)
    
    quitBtn = Button(root,text="Quit",bg='yellow', fg='black', command=root.destroy)
    quitBtn.place(relx=0.53,rely=0.9, relwidth=0.18,relheight=0.08)
    
    root.mainloop()
def signup():
    
    user=userInfo.get()
    password=passInfo.get()
    email=emailInfo.get()
    
    query = "insert into users(Usename,EmailId,PASSWORD)values('"+user+"','"+email+"','"+password+"')"
    
    try:
        cur.execute(query)
        con.commit()
        messagebox.showinfo("Success","You've signed up successfully..!!")
        

    except:
        messagebox.showinfo("Error","You couldn't sign up..:(")
        
    else:
        root=Tk()
        root.geometry("900x900")
        root.maxsize(900,900)
        root.title("Library")
        
        Canvas1 = Canvas(root)
        Canvas1.config(bg="yellow")
        Canvas1.pack(expand=True,fill=BOTH)

        headingFrame = Frame(root,bd=5)
        headingFrame.place(relx=0.2,rely=0.1,relwidth=0.6,relheight=0.16)
        headingLabel = Label(headingFrame, text="Welcome to \n The Grand Library", bg='black', fg='white', font="comicsans 19 bold",borderwidth=3,relief=RIDGE)
        headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)

        btn1 = Button(root,text="Add Book Details",bg='black', fg='red', font="comicsansms 14 italic",command=addBook)
        btn1.place(relx=0.30,rely=0.3, relwidth=0.4,relheight=0.1)

        btn2 = Button(root,text="Delete Book",bg='black', fg='blue',font="comicsansms 14 italic", command=delete)
        btn2.place(relx=0.30,rely=0.4, relwidth=0.4,relheight=0.1)

        btn3 = Button(root,text="View Book List",bg='black', fg='green',font="comicsansms 14 italic", command=view)
        btn3.place(relx=0.30,rely=0.5, relwidth=0.4,relheight=0.1)

        btn4 = Button(root,text="Issue Book to Client",bg='black', fg='yellow',font="comicsansms 14 italic", command = issueBook)
        btn4.place(relx=0.30,rely=0.6, relwidth=0.4,relheight=0.1)

        btn5 = Button(root,text="Return Book",bg='black', fg='red',font="comicsansms 14 italic", command = returnBook)
        btn5.place(relx=0.30,rely=0.7, relwidth=0.4,relheight=0.1)
        
        btn6 = Button(root,text="View Candidate Detail",bg='black', fg='blue',font="comicsansms 14 italic", command = candDetail)
        btn6.place(relx=0.30,rely=0.8, relwidth=0.4,relheight=0.1)

        root.mainloop()


def loginPage():
    
    global userInfo1,passInfo1,con,cur,root
    
    root = Tk()
    root.title("Login")
    root.maxsize(500,500) 
    root.geometry("500x500")
    
    Canvas1 = Canvas(root)
    Canvas1.config(bg="black")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg='red')
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.1)

    headingLabel = Label(headingFrame1, text="Please Log In", bg='red', font="Comicsansms 19 italic")
    headingLabel.pack()


    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.4,relwidth=0.8,relheight=0.4)
        
    lb1 = Label(labelFrame,text="Username : ", bg='black', fg='white')
    lb1.place(relx=0.05,rely=0.2, relheight=0.08)
        
    userInfo1 = Entry(labelFrame)
    userInfo1.place(relx=0.3,rely=0.2, relwidth=0.62, relheight=0.08)
    
    lb2 = Label(labelFrame,text="Password : ", bg='black', fg='white')
    lb2.place(relx=0.05,rely=0.35, relheight=0.08)
        
    passInfo1 = Entry(labelFrame)
    passInfo1.place(relx=0.3,rely=0.35, relwidth=0.62, relheight=0.08)
    
    loginBtn = Button(root,text="Log In",bg='green', fg='black',command=login)
    loginBtn.place(relx=0.28,rely=0.9, relwidth=0.18,relheight=0.08)
    
    quitBtn = Button(root,text="Quit",bg='yellow', fg='black', command=root.destroy)
    quitBtn.place(relx=0.53,rely=0.9, relwidth=0.18,relheight=0.08)

def login():
    global Canvas1,label
    user= userInfo1.get()
    password=passInfo1.get()
    
    Query1 = "select Usename from users"
    
    try:
        cur.execute(Query1)
        con.commit()
        allusers=[]
        for i in cur:
            allusers.append(i[0])
        if user in allusers:
            checkpass = "select PASSWORD from users where Usename = '"+user+"'"
            cur.execute(checkpass)
            con.commit()
            for i in cur:
                check = i[0]
        
                
            if check == password:
                passw=True
            else:
                passw=False

        else:
            messagebox.showinfo("Error","Please enter your registered name and correct password")
            
    except:
        messagebox.showinfo("Error","Check your name and password")
        
    if passw==True:
        messagebox.showinfo("Success","You've Logged in successfully")
        
        root=Tk()
        root.geometry("900x900")
        root.maxsize(900,900)
        root.title("Library")
        
        Canvas1 = Canvas(root)
        Canvas1.config(bg="medium orchid")
        Canvas1.pack(expand=True,fill=BOTH)

        headingFrame = Frame(root,bd=5)
        headingFrame.place(relx=0.2,rely=0.1,relwidth=0.6,relheight=0.16)
        headingLabel = Label(headingFrame, text="Welcome to \n The Grand Library", bg='black', fg='white', font="Comicsansms 22 bold",borderwidth=3,relief=RIDGE)
        headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)

        btn1 = Button(root,text="Add Book Details",bg='black', fg='red', font="comicsansms 14 italic",command=addBook)
        btn1.place(relx=0.30,rely=0.3, relwidth=0.4,relheight=0.1)

        btn2 = Button(root,text="Delete Book",bg='black', fg='blue',font="comicsansms 14 italic", command=delete)
        btn2.place(relx=0.30,rely=0.4, relwidth=0.4,relheight=0.1)

        btn3 = Button(root,text="View Book List",bg='black', fg='green',font="comicsansms 14 italic", command=view)
        btn3.place(relx=0.30,rely=0.5, relwidth=0.4,relheight=0.1)

        btn4 = Button(root,text="Issue Book to Client",bg='black', fg='yellow',font="comicsansms 14 italic", command = issueBook)
        btn4.place(relx=0.30,rely=0.6, relwidth=0.4,relheight=0.1)

        btn5 = Button(root,text="Return Book",bg='black', fg='red',font="comicsansms 14 italic", command = returnBook)
        btn5.place(relx=0.30,rely=0.7, relwidth=0.4,relheight=0.1)
        
        btn6 = Button(root,text="View Candidate Detail",bg='black', fg='blue',font="comicsansms 14 italic", command = candDetail)
        btn6.place(relx=0.30,rely=0.8, relwidth=0.4,relheight=0.1)

        root.mainloop()

    allusers.clear()
    
def addBook():
    
    global bookInfo1 ,bookInfo2, bookInfo3, bookInfo4, Canvas1, con, cur, root
    
    root = Tk()
    root.title("Add Book to Library")
    root.maxsize(500,500) 
    root.geometry("500x500")

    con = pymysql.connect( host="localhost",user="root",password='',database="db1")
    cur = con.cursor()

    Canvas1 = Canvas(root)
    Canvas1.config(bg="blue")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg='yellow')
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.1)

    headingLabel = Label(headingFrame1, text="Add Book", bg='yellow', font="comicsansms 19 italic")
    headingLabel.pack()


    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.4,relwidth=0.8,relheight=0.4)
        
    lb1 = Label(labelFrame,text="Book ID : ", bg='black', fg='white')
    lb1.place(relx=0.05,rely=0.2, relheight=0.08)
        
    bookInfo1 = Entry(labelFrame)
    bookInfo1.place(relx=0.3,rely=0.2, relwidth=0.62, relheight=0.08)
        
    lb2 = Label(labelFrame,text="Title : ", bg='black', fg='white')
    lb2.place(relx=0.05,rely=0.35, relheight=0.08)
        
    bookInfo2 = Entry(labelFrame)
    bookInfo2.place(relx=0.3,rely=0.35, relwidth=0.62, relheight=0.08)
        
    lb3 = Label(labelFrame,text="Author : ", bg='black', fg='white')
    lb3.place(relx=0.05,rely=0.50, relheight=0.08)
        
    bookInfo3 = Entry(labelFrame)
    bookInfo3.place(relx=0.3,rely=0.50, relwidth=0.62, relheight=0.08)
        
    lb4 = Label(labelFrame,text="Status(Available\n/issued) : ", bg='black', fg='white')
    lb4.place(relx=0.05,rely=0.65, relheight=0.2)
        
    bookInfo4 = Entry(labelFrame)
    bookInfo4.place(relx=0.3,rely=0.65, relwidth=0.62, relheight=0.1)
        
    SubmitBtn = Button(root,text="SUBMIT",bg='green', fg='black',command=bookRegister)
    SubmitBtn.place(relx=0.28,rely=0.9, relwidth=0.18,relheight=0.08)
    
    quitBtn = Button(root,text="Quit",bg='red', fg='black', command=root.destroy)
    quitBtn.place(relx=0.53,rely=0.9, relwidth=0.18,relheight=0.08)

def bookRegister():
    bid = bookInfo1.get()
    title = bookInfo2.get()
    author = bookInfo3.get()
    status = bookInfo4.get()
    status = status.lower()
    
    insertBookQuery = "insert into book values ('"+bid+"','"+title+"','"+author+"','"+status+"')"
    try:
        cur.execute(insertBookQuery)
        con.commit()
        messagebox.showinfo('Success',"Book added successfully")
    except:
        messagebox.showinfo("Error","Can't add data into Database")
    
    print(bid)
    print(title)
    print(author)
    print(status)
    
def delete(): 
    global bookInfo,Canvas1,con,cur,bookTable,root
    
    root = Tk()
    root.title("Library")
    root.minsize(width=400,height=400)
    root.geometry("600x500")


    Canvas1 = Canvas(root)
    Canvas1.config(bg="red")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg="white",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)
        
    headingLabel = Label(headingFrame1, text="Delete Book", bg='red', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)
    
    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.3,relwidth=0.8,relheight=0.5)   
        
    lb2 = Label(labelFrame,text="Book ID : ", bg='black', fg='white')
    lb2.place(relx=0.05,rely=0.5)
        
    bookInfo = Entry(labelFrame)
    bookInfo.place(relx=0.3,rely=0.5, relwidth=0.5)
    
    delBtn = Button(root,text="Delete",bg='orange', fg='black',command=deleteBook)
    delBtn.place(relx=0.28,rely=0.9, relwidth=0.18,relheight=0.08)
    
    quitBtn = Button(root,text="Quit",bg='blue', fg='black', command=root.destroy)
    quitBtn.place(relx=0.53,rely=0.9, relwidth=0.18,relheight=0.08)
    
def deleteBook():
    
    bid = bookInfo.get()
    
    deleteFrombook = "delete from book where bid = '"+bid+"'"
    deleteFrombooks_issued = "delete from books_issued where bid = '"+bid+"'"

    try:
        cur.execute(deleteFrombook)
        con.commit()
        cur.execute(deleteFrombooks_issued)
        con.commit()

        messagebox.showinfo('Success',"Book Record Deleted Successfully")

    except:
        messagebox.showinfo("Please check Book ID")
    
    print(f'book id:{bid} has been deleted')
    
def view():
    root = Tk()
    root.title("Library")
    root.minsize(width=400,height=400)
    root.geometry("600x500")

    Canvas1 = Canvas(root) 
    Canvas1.config(bg="pink")
    Canvas1.pack(expand=True,fill=BOTH)

    headingFrame1 = Frame(root,bg="yellow",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)

    headingLabel = Label(headingFrame1, text="View Books", bg='black', fg='white', font ='Courier 15 italic')
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)

    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.3,relwidth=0.8,relheight=0.5)

    Label(labelFrame, text="%-10s%-40s%-40s%-60s"%('BID','Title','\tAuthor','\tStatus'), bg='black',fg='white').place(relx=0.07,rely=0.1)
    Label(labelFrame, text = "---------------------------------------------------------------------------------------",bg='black',fg='white').place (relx=0.05,rely=0.2)
    getBooks = "select * from book"
    try:
        cur.execute(getBooks)
        con.commit()

        y = 0.25
        for i in cur:
            Label(labelFrame,text="%-10s%-40s%-30s%-40s"%(i[0],i[1],i[2],i[3]) ,bg='black', fg='white').place(relx=0.07,rely=y)
            y += 0.1
    except:
        messagebox.showinfo("Failed to fetch files from database")
    
    quitBtn = Button(root,text="Quit",bg='red', fg='black', command=root.destroy)
    quitBtn.place(relx=0.4,rely=0.9, relwidth=0.18,relheight=0.08)

def issueBook():
    global issueBtn,quitBtn,labelFrame,lb1,inf1,inf2,root,Canvas1,status
    
    root = Tk()
    root.title("Library")
    root.minsize(width=400,height=400)
    root.geometry("600x500")
    
    Canvas1 = Canvas(root)
    Canvas1.config(bg="green")
    Canvas1.pack(expand=True,fill=BOTH)
    headingFrame1 = Frame(root,bg="white",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)
        
    headingLabel = Label(headingFrame1, text="Issue Book", bg='white', fg='black', font='Courier 15 italic' )
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)
    
    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.3,relwidth=0.8,relheight=0.5)  
        
    lb1 = Label(labelFrame,text="Book ID : ", bg='black', fg='white')
    lb1.place(relx=0.05,rely=0.2)
        
    inf1 = Entry(labelFrame)
    inf1.place(relx=0.3,rely=0.2, relwidth=0.62)
    
    lb2 = Label(labelFrame,text="Issued To : ", bg='black', fg='white')
    lb2.place(relx=0.05,rely=0.4)
        
    inf2 = Entry(labelFrame)
    inf2.place(relx=0.3,rely=0.4, relwidth=0.62)
    
    issueBtn = Button(root,text="Issue",bg='blue', fg='black',command=issue)
    issueBtn.place(relx=0.28,rely=0.9, relwidth=0.18,relheight=0.08)
    
    quitBtn = Button(root,text="Quit",bg='red', fg='black', command=root.destroy)
    quitBtn.place(relx=0.53,rely=0.9, relwidth=0.18,relheight=0.08)
    
def issue():
    global issueBtn,labelFrame,lb1,inf1,inf2,quitBtn,root,Canvas1,status,allBid
    
    bid = inf1.get()
    issueto = inf2.get()
    extractBid = "select bid from book"
    try:
        cur.execute(extractBid)
        con.commit()
        allBid=[]
        for i in cur:
            allBid.append(i[0])
        
        if bid in allBid:
            checkAvail = "select status from book where bid = '"+bid+"'"
            cur.execute(checkAvail)
            con.commit()
            for i in cur:
                check = i[0]
                
            if check == 'available':
                status = True
            else:
                status = False

        else:
            messagebox.showinfo("Error","Book ID is not present")
    except:
        messagebox.showinfo("Error","Can't fetch Book ID")
    
    issueSql = "insert into books_issued values ('"+bid+"','"+issueto+"')"
    show = "select * from books_issued"
    
    updateStatus = "update book set status = 'issued' where bid = '"+bid+"'"
    try:
        if bid in allBid and status == True:
            cur.execute(issueSql)
            con.commit()
            cur.execute(updateStatus)
            con.commit()
            messagebox.showinfo('Success',"Book Issued Successfully")
            root.destroy()
        else:
            allBid.clear()
            messagebox.showinfo('Message',"Book Already Issued")
            root.destroy()
            return
    except:
        messagebox.showinfo("Search Error","The value entered is wrong, Try again")

    print(bid)
    print(issueto)
    
    allBid.clear()
    
def returnBook():
    global bookInfo1,SubmitBtn,quitBtn,Canvas1,con,cur,root,labelFrame, lb1
    
    root = Tk()
    root.title("Library")
    root.minsize(width=400,height=400)
    root.geometry("600x500")


    Canvas1 = Canvas(root)
    
    Canvas1.config(bg="yellow")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg="green",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)
        
    headingLabel = Label(headingFrame1, text="Return Book", bg='green', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)
    
    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.3,relwidth=0.8,relheight=0.5)   
        
    lb1 = Label(labelFrame,text="Book ID : ", bg='black', fg='white')
    lb1.place(relx=0.05,rely=0.5)
        
    bookInfo1 = Entry(labelFrame)
    bookInfo1.place(relx=0.3,rely=0.5, relwidth=0.62)
    
    SubmitBtn = Button(root,text="Return",bg='blue', fg='black',command=returnn)
    SubmitBtn.place(relx=0.28,rely=0.9, relwidth=0.18,relheight=0.08)
    
    quitBtn = Button(root,text="Quit",bg='grey', fg='black', command=root.destroy)
    quitBtn.place(relx=0.53,rely=0.9, relwidth=0.18,relheight=0.08)

def returnn():
    
    global SubmitBtn,labelFrame,lb1,bookInfo1,quitBtn,root,Canvas1,status,allBid
    
    bid = bookInfo1.get()
    allBid=[]
    extractBid = "select bid from books_issued"
    try:
        cur.execute(extractBid)
        con.commit()
        for i in cur:
            allBid.append(i[0])
        
        if bid in allBid:
            checkAvail = "select status from book where bid = '"+bid+"'"
            cur.execute(checkAvail)
            con.commit()
            for i in cur:
                check = i[0]
                
            if check == 'issued':
                status = True
            else:
                status = False

        else:
            messagebox.showinfo("Error","Book ID not present")
    except:
        messagebox.showinfo("Error","Can't fetch Book IDs")
    
    
    issueSql = "delete from books_issued where bid = '"+bid+"'"
    
    updateStatus = "update book set status = 'available' where bid = '"+bid+"'"
    try:
        if bid in allBid and status == True:
            cur.execute(issueSql)
            con.commit()
            cur.execute(updateStatus)
            con.commit()
            messagebox.showinfo('Success',"Book Returned Successfully")
        else:
            allBid.clear()
            messagebox.showinfo('Message',"Please check the book ID")
            root.destroy()
            return
    except:
        messagebox.showinfo("Search Error","The value entered is wrong, Try again")
    
    
    allBid.clear()
    root.destroy()
    

def candDetail():
    root = Tk()
    root.title("Candidate Details")
    root.minsize(width=400,height=400)
    root.geometry("600x500")

    Canvas1 = Canvas(root) 
    Canvas1.config(bg="sea green")
    Canvas1.pack(expand=True,fill=BOTH)

    headingFrame1 = Frame(root,bg="yellow",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)

    headingLabel = Label(headingFrame1, text="View Candidates", bg='black', fg='white', font ='Courier 15 italic')
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)
    

    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.27,relwidth=0.8,relheight=0.6)

    Label(labelFrame, text="%-10s%-40s%-40s"%('User ID','User Name','\tEmail ID'), bg='black',fg='white').place(relx=0.07,rely=0.1)
    Label(labelFrame, text = "---------------------------------------------------------------------------------------",bg='black',fg='white').place (relx=0.05,rely=0.2)
    
    getUsers = "select UserID,Usename,EmailID from users"
    try:
        cur.execute(getUsers)
        con.commit()

        y = 0.25
        for i in cur:
            l1=Label(labelFrame,text="%-10s%-40s%-40s"%(i[0],i[1],i[2]) ,bg='black', fg='white')
            l1.place(relx=0.07,rely=y)
            y += 0.1
    except:
        messagebox.showinfo("Failed to fetch files from database")
    
    quitBtn = Button(root,text="Quit",bg='red', fg='black', command=root.destroy)
    quitBtn.place(relx=0.4,rely=0.9, relwidth=0.18,relheight=0.08)
    
root=Tk()
root.title("Log In or Sign Up")
root.geometry("900x800")
root.maxsize(900,800)

img1=Image.open("imagess.jpg")
img1=img1.resize((900,800),Image.ANTIALIAS)
photo1=ImageTk.PhotoImage(img1)
label1=Label(image=photo1)
label1.pack()


lbl=Label(root,text="Sign Up if you are new here or\n Log In if you're already a member of The Grand Library ",bg="orchid",fg="white",font="Comicsansms 19 bold",borderwidth=5,relief=SUNKEN)
lbl.place(relx=0.14,rely=0.07)
b1=Button(root,fg="red",text="Sign Up",font="Comicsansms 15 italic",bg="LavenderBlush1",command=signupPage)
b1.place(relx=0.35,rely=0.4,relheight=0.10,relwidth=0.3)
b2=Button(root,fg="red",text="Log In",font="Comicsansms 15 italic",bg="LavenderBlush1",command=loginPage)
b2.place(relx=0.35,rely=0.5,relheight=0.10,relwidth=0.3)    

root.mainloop()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3648\3275687069.py:605: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   img1=img1.resize((900,800),Image.ANTIALIAS)
